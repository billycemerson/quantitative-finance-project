# %% [markdown]
# <a href="https://colab.research.google.com/github/billycemerson/quantitative-finance-project/blob/main/01_foundations/intro_to_yfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %% [markdown]
# ## Stock

# %% [markdown]
# See detail here: https://ranaroussi.github.io/yfinance/reference/yfinance.stock.html

# %%
Ticker = yf.Ticker("BBCA.JK")

# %% [markdown]
# #### Historical Data

# %%
data = Ticker.history(period="max", interval="1d")
data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2004-06-08 00:00:00+07:00    97.646418   100.436315    97.646418    99.041367
# 2004-06-09 00:00:00+07:00    99.041376   101.831274    97.646427   100.436325
# 2004-06-10 00:00:00+07:00   100.436325   100.436325    99.041376   100.436325
# 2004-06-11 00:00:00+07:00    99.041376   100.436325    99.041376   100.436325
# 2004-06-14 00:00:00+07:00   100.436315   100.436315    97.646418    99.041367
# ...                                ...          ...          ...          ...
# 2025-12-09 00:00:00+07:00  8300.000000  8300.000000  8100.000000  8100.000000
# 2025-12-10 00:00:00+07:00  8100.000000  8175.000000  8025.000000  8075.000000
# 2025-12-11 00:00:00+07:00  8175.000000  8200.000000  7900.000000  8000.000000
# 2025-12-12 00:00:00+07:00  7900.000000  8000.000000  7850.000000  8000.000000
# 2025-12-15 00:00:00+07:00  7925.000000  8300.000000  7925.000000  8300.000000
#
# ...

# %% [markdown]
# #### Ticker Info

# %%
Ticker.info
# Out:
# {'address1': 'Menara BCA, Grand Indonesia',
#  'address2': 'Jl. M.H. Thamrin No. 1',
#  'city': 'Jakarta',
#  'zip': '10310',
#  'country': 'Indonesia',
#  'phone': '62 21 2358 8000',
#  'fax': '62 21 2358 8300',
#  'website': 'https://www.bca.co.id',
#  'industry': 'Banks - Regional',
#  'industryKey': 'banks-regional',
#  'industryDisp': 'Banks - Regional',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
# ...

# %%
industry = Ticker.info["industry"]
industry
# Out:
# 'Banks - Regional'

# %%
rec = Ticker.info["recommendationKey"]
rec
# Out:
# 'strong_buy'

# %% [markdown]
# #### Ticker News

# %%
news = Ticker.news
news
# Out:
# [{'id': '056750c0-27d2-3277-a21f-572c71101a55',
#   'content': {'id': '056750c0-27d2-3277-a21f-572c71101a55',
#    'contentType': 'STORY',
#    'title': 'Financial Services Roundup: Market Talk',
#    'description': '',
#    'summary': 'Find insight on Bank Syariah Indonesia, Thai Life Insurance and more in the latest Market Talks covering Financial Services.',
#    'pubDate': '2025-12-15T12:06:00Z',
#    'displayTime': '2025-12-15T12:06:00Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/056750c0-27d2-3277-a21f-572c71101a55/financial-services-roundup-.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/wsj.com/6ced8ee41e942455fdb4bb8c1c6e6109',
#     'originalWidth': 1280,
#     'originalHeight': 640,
#     'caption': '',
# ...

# %% [markdown]
# #### Ticker Dividens

# %%
div = Ticker.dividends
div
# Out:
# Date
# 2004-07-01 00:00:00+07:00     22.5
# 2004-11-23 00:00:00+07:00      5.0
# 2005-07-20 00:00:00+07:00      8.0
# 2005-10-07 00:00:00+07:00      5.0
# 2006-06-07 00:00:00+07:00      9.0
# 2006-10-11 00:00:00+07:00      5.5
# 2007-06-11 00:00:00+07:00     11.5
# 2007-11-30 00:00:00+07:00      5.5
# 2008-06-13 00:00:00+07:00     12.7
# 2009-01-16 00:00:00+07:00      7.0
# 2009-06-10 00:00:00+07:00     13.0
# 2009-11-13 00:00:00+07:00      8.0
# 2010-06-01 00:00:00+07:00     14.0
# 2010-11-22 00:00:00+07:00      8.5
# 2011-06-07 00:00:00+07:00     14.0
# 2011-12-07 00:00:00+07:00      8.7
# 2012-06-11 00:00:00+07:00     14.0
# 2012-12-04 00:00:00+07:00      8.7
# 2013-05-29 00:00:00+07:00     14.2
# 2013-11-29 00:00:00+07:00      9.0
# 2014-04-30 00:00:00+07:00     15.0
# 2014-12-05 00:00:00+07:00     10.0
# 2015-04-17 00:00:00+07:00     19.6
# 2015-11-13 00:00:00+07:00     11.0
# 2016-04-15 00:00:00+07:00     21.0
# 2016-12-01 00:00:00+07:00     14.0
# ...

# %% [markdown]
# ## Market

# %% [markdown]
# See detail here:
# https://ranaroussi.github.io/yfinance/reference/yfinance.market.html

# %%
ASIA = yf.Market("ASIA")

# %% [markdown]
# #### Market Status

# %%
status = ASIA.status
status
# Out:
# {'id': 'us',
#  'name': 'U.S. markets',
#  'status': 'open',
#  'yfit_market_id': 'us_market',
#  'close': datetime.datetime(2025, 12, 15, 21, 0, tzinfo=datetime.timezone.utc),
#  'duration': [{'hrs': '6', 'mins': '12'}],
#  'message': 'U.S. markets close in 6 hours 12 minutes',
#  'open': datetime.datetime(2025, 12, 15, 14, 30, tzinfo=datetime.timezone.utc),
#  'yfit_market_status': 'YFT_MARKET_WILL_CLOSE',
#  'timezone': {'dst': 'false',
#   'gmtoffset': '-18000',
#   'short': 'EST',
#   '$text': 'America/New_York'},
#  'tz': datetime.timezone(datetime.timedelta(days=-1, seconds=21600), 'EST')}

# %% [markdown]
# #### Market Summary

# %%
summary = ASIA.summary
summary
# Out:
# {'SHH': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'marketState': 'POSTPOST',
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 15,
#   'exchangeTimezoneName': 'Asia/Shanghai',
#   'exchangeTimezoneShortName': 'CST',
#   'gmtOffSetMilliseconds': 28800000,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'regularMarketChange': -21.424805,
#   'regularMarketChangePercent': -0.55085886,
#   'regularMarketTime': 1765782024,
#   'regularMarketPrice': 3867.921,
#   'regularMarketPreviousClose': 3889.3457,
#   'exchange': 'SHH',
#   'market': 'cn_market',
#   'fullExchangeName': 'Shanghai',
#   'shortName': 'SSE Composite Index',
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': 867807000000,
#   'priceHint': 2,
#   'symbol': '000001.SS'},
#  'OSA': {'language': 'en-US',
# ...

# %%
CRYPTO = yf.Market("CRYPTOCURRENCIES")
CRYPTO.status
# Out:
# {'id': 'us',
#  'name': 'U.S. markets',
#  'status': 'open',
#  'yfit_market_id': 'us_market',
#  'close': datetime.datetime(2025, 12, 15, 21, 0, tzinfo=datetime.timezone.utc),
#  'duration': [{'hrs': '6', 'mins': '10'}],
#  'message': 'U.S. markets close in 6 hours 10 minutes',
#  'open': datetime.datetime(2025, 12, 15, 14, 30, tzinfo=datetime.timezone.utc),
#  'yfit_market_status': 'YFT_MARKET_WILL_CLOSE',
#  'timezone': {'dst': 'false',
#   'gmtoffset': '-18000',
#   'short': 'EST',
#   '$text': 'America/New_York'},
#  'tz': datetime.timezone(datetime.timedelta(days=-1, seconds=21600), 'EST')}

# %%
CRYPTO.summary
# Out:
# {'CCC': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'CRYPTOCURRENCY',
#   'typeDisp': 'Cryptocurrency',
#   'quoteSourceName': 'CoinMarketCap',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'shortName': 'Solana USD',
#   'regularMarketPreviousClose': 129.48228,
#   'exchange': 'CCC',
#   'market': 'ccc_market',
#   'fullExchangeName': 'CCC',
#   'marketState': 'REGULAR',
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': 1586476800000,
#   'regularMarketChange': 2.1339264,
#   'regularMarketChangePercent': 1.6315662,
#   'regularMarketTime': 1765809840,
#   'regularMarketPrice': 132.92374,
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 0,
#   'exchangeTimezoneName': 'UTC',
#   'exchangeTimezoneShortName': 'UTC',
#   'gmtOffSetMilliseconds': 0,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': True,
#   'symbol': 'SOL-USD'}}

# %% [markdown]
# ## Financials

# %% [markdown]
# See detail here: https://ranaroussi.github.io/yfinance/reference/yfinance.financials.html

# %%
Ticker = yf.Ticker("BBCA.JK")

# %% [markdown]
# #### Income Statement

# %%
inc_statement = Ticker.income_stmt
inc_statement
# Out:
#                                                       2024-12-31  \
# Tax Effect Of Unusual Items                         1.637702e+11
# Tax Rate For Calcs                                  1.959400e-01
# Total Unusual Items                                 8.358200e+11
# Total Unusual Items Excluding Goodwill              8.358200e+11
# Net Income From Continuing Operation Net Minori...  5.483630e+13
# Reconciled Depreciation                             2.167549e+12
# Net Interest Income                                 8.436079e+13
# Interest Expense                                    9.885265e+12
# Interest Income                                     9.424605e+13
# Normalized Income                                   5.416426e+13
# Net Income From Continuing And Discontinued Ope...  5.483630e+13
# Diluted Average Shares                              1.232750e+11
# Basic Average Shares                                1.232750e+11
# ...

# %% [markdown]
# #### Balance Sheet

# %%
bs = Ticker.balance_sheet
bs
# Out:
#                                                       2024-12-31  \
# Treasury Shares Number                                       NaN
# Ordinary Shares Number                              1.232750e+11
# Share Issued                                        1.232750e+11
# Total Debt                                          3.044409e+12
# Tangible Book Value                                 2.608350e+14
# Invested Capital                                    2.653826e+14
# Net Tangible Assets                                 2.608350e+14
# Common Stock Equity                                 2.626406e+14
# Total Capitalization                                2.653826e+14
# Total Equity Gross Minority Interest                2.628351e+14
# Minority Interest                                   1.944660e+11
# Stockholders Equity                                 2.626406e+14
# Other Equity Interest                               1.385000e+09
# ...

# %% [markdown]
# #### Cashflow

# %%
cash = Ticker.cashflow
cash
# Out:
#                                                     2024-12-31    2023-12-31  \
# Free Cash Flow                                    4.964705e+13  5.296443e+13
# Repayment Of Debt                                -7.268002e+13 -4.960767e+13
# Issuance Of Debt                                  7.328773e+13  4.992882e+13
# Capital Expenditure                              -4.173179e+12 -5.099348e+12
# End Cash Position                                 8.548253e+13  1.243960e+14
# Beginning Cash Position                           1.243960e+14  1.604224e+14
# Effect Of Exchange Rate Changes                  -4.564910e+11  7.255800e+11
# Changes In Cash                                  -3.845697e+13 -3.675196e+13
# Financing Cash Flow                              -3.332869e+13 -2.507068e+13
# Net Other Financing Charges                       2.724260e+11  8.041130e+11
# Cash Dividends Paid                              -3.420883e+13 -2.619595e+13
# ...

# %% [markdown]
# ## Analysis & Holdings

# %% [markdown]
# See detail here: https://ranaroussi.github.io/yfinance/reference/yfinance.analysis.html

# %% [markdown]
# #### Get Recommendation

# %%
rec = Ticker.recommendations
rec
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          3   18     1     0           0
# 1    -1m          3   18     1     0           0
# 2    -2m          3   19     1     0           0
# 3    -3m          4   17     1     0           0

# %% [markdown]
# #### Sustainability

# %%
sustain = Ticker.sustainability
sustain
# Out:
# ERROR:yfinance:HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: BBCA.JK"}}}
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Price Target

# %%
target = Ticker.analyst_price_targets
target
# Out:
# {'current': 8300.0,
#  'high': 12400.0,
#  'low': 8000.0,
#  'mean': 10527.5,
#  'median': 10380.0}

# %% [markdown]
# #### Earnings Estimate

# %%
earn_estim = Ticker.earnings_estimate
earn_estim
# Out:
#               avg     low    high  yearAgoEps  numberOfAnalysts  growth
# period
# 0q      107.67500  106.68  108.67   112.00000                 2 -0.0386
# +1q     120.42000  120.42  120.42   115.00000                 1  0.0471
# 0y      465.12723  457.00  480.10   445.00000                19  0.0452
# +1y     495.66670  459.03  546.00   465.12723                20  0.0657

# %% [markdown]
# #### Another Analysis

# %%
Ticker.eps_trend
# Out:
#           current   7daysAgo  30daysAgo  60daysAgo  90daysAgo
# period
# 0q      107.67500  107.79500  105.60000  104.71667  104.71667
# +1q     120.42000  114.64000  114.64000  117.46000  118.62000
# 0y      465.12723  465.46356  467.23724  469.39030  468.23752
# +1y     495.66670  495.89670  498.92978  502.84300  501.07720

# %%
Ticker.eps_revisions
# Out:
#         upLast7days  upLast30days  downLast30days  downLast7Days
# period
# 0q                0             0               0              0
# +1q               1             1               0              0
# 0y                0             1               4              1
# +1y               1             1               5              0

# %%
Ticker.growth_estimates
# Out:
#         stockTrend  indexTrend
# period
# 0q         -0.0386      0.1524
# +1q         0.0471      0.0680
# 0y          0.0452      0.1090
# +1y         0.0657      0.1480
# LTG            NaN      0.1220

# %%
Ticker.major_holders
# Out:
# Breakdown                         Value
# insidersPercentHeld             0.59702
# institutionsPercentHeld         0.21737
# institutionsFloatPercentHeld    0.53939
# institutionsCount             413.00000

# %%
Ticker.institutional_holders
# Out:
#   Date Reported               Holder  pctHeld  Shares     Value  pctChange
# 0    2025-03-31  Gamma Investing LLC      0.0   11522  95632600    -0.8411

# %%
Ticker.mutualfund_holders
# Out:
#   Date Reported                                             Holder  pctHeld  \
# 0    2025-07-31  Goldman Sachs TRT II-Goldman Sachs GQG Part. I...   0.0080
# 1    2025-07-31  VANGUARD STAR FUNDS-Vanguard Total Internation...   0.0058
# 2    2025-07-31  VANGUARD Intl Eqy. INDEX Fd.S-Vanguard Emergin...   0.0054
# 3    2025-09-30  ADVISORS' INNER CIRCLE III-GQG PARTNERS EMERGI...   0.0047
# 4    2025-09-30  iShares, Inc.-iShares Core MSCI Emerging Marke...   0.0045
# 5    2025-07-31  AIM Investment Fd.s -Invesco Developing Market...   0.0041
# 6    2025-09-30                 EuroPacific Growth Fund-EUPAC Fund   0.0040
# 7    2025-09-30  Fidelity Investment Trust-Fidelity Emerging Ma...   0.0035
# 8    2025-09-30  Fidelity Rutland Square TRT II-Strategic Advis...   0.0030
# 9    2025-09-30  -Price (T.Rowe) International Growth Equity Trust   0.0028
#
#       Shares          Value  pctChange
# 0  978524598  8121754163400    -0.0671
# 1  712969797  5917649315100    -0.0957
# ...

# %%
Ticker.insider_purchases
# Out:
#        Insider Purchases Last 6m       Shares  Trans
# 0                      Purchases            0      0
# 1                          Sales         <NA>      0
# 2    Net Shares Purchased (Sold)            0      0
# 3      Total Insider Shares Held  73580756992   <NA>
# 4  % Net Shares Purchased (Sold)         <NA>   <NA>
# 5                   % Buy Shares         <NA>   <NA>
# 6                  % Sell Shares         <NA>   <NA>
